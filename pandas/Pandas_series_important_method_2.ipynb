# %% [markdown]
# <a href="https://colab.research.google.com/github/iamanish9189/python-for-data-analysis/blob/main/pandas/Pandas_series_important_method_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# astype
# between
# clip
# drop_doplicates
# isnull
# dropna
# fillna
# isin
# copy
# apply

# %%
import numpy as np
import pandas as pd

# %%
subs = pd.read_csv('/content/subs.csv').squeeze()
type(subs)

# %%
vk = pd.read_csv("/content/kohli_ipl.csv",index_col='match_no').squeeze()
type(vk)

# %%
movies = pd.read_csv("/content/bollywood.csv",index_col='movie').squeeze()
type(movies)

# %%
# astype -> change data type
import sys
sys.getsizeof(vk)

# %%
sys.getsizeof(vk.astype('int16'))

# %%
# between --> ek range ke under values exist karti hai ye nhi ye nikal kar btata hai
# boolean returns
virat = vk.between(51,99)
vk[virat]

# %%
# clip
subs.clip(100,200)

# %%
# drop_doplicates
temp = pd.Series([1,1,2,2,3,3,4,4])
temp

# %%
temp.drop_duplicates(keep = 'last')

# %%
type(movies)

# %%
movies.drop_duplicates()

# %%
print(vk.duplicated().sum())

# %%
temp1 = pd.Series([1,2,3,np.nan,5,6,np.nan,8,np.nan,10])
temp1

# %%
# isnull
temp1.size

# %%
print(temp1.count())

# %%
temp1.isnull().sum()

# %%
# dropna --> removes missing values
temp1.dropna()

# %%
# fillna --> fill the values
temp1.fillna(temp1.mean())

# %%
# isin
vk[(vk == 49) | (vk == 99)]

# %%
vk[vk.isin([49,99])]

# %%
# apply
movies

# %%
movies.apply(lambda x:x.split()[0].upper())

# %%
subs.mean()

# %%
subs.apply(lambda x:"Good day" if x > subs.mean() else 'Bad day')

# %%
# copy
vk

# %%
new = vk.head().copy()

# %%
new

# %%
new[1] = 1

# %%
new

# %%
new[1] = 100

# %%
new

# %%
vk
